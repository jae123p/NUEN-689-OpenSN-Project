# %%
import openmc
import openmc.mgxs
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas
import h5py
# %matplotlib inline

# %%
import os

# %%
os.environ['PATH'] += r':/home/jae123p/miniconda3/envs/openmc-env/bin'

# %env OPENMC_CROSS_SECTIONS=/home/jae123p/endfb80/endfb-viii.0-hdf5/cross_sections.xml
# Out:
# env: OPENMC_CROSS_SECTIONS=/home/jae123p/endfb80/endfb-viii.0-hdf5/cross_sections.xml

# %%
model = openmc.Model()

# %%
oralloy = openmc.Material(name="Oralloy")
oralloy.add_nuclide('U234', 4.9210e-04)
oralloy.add_nuclide('U235', 4.4917e-02)
oralloy.add_nuclide('U238', 2.5993e-03)

materials = openmc.Materials([oralloy])

# %%
model.materials = openmc.Materials([oralloy])

# %%
box = openmc.model.RectangularPrism(width=10, height = 10, boundary_type='reflective')
mat_cell = openmc.Cell(name='OralloyCell', fill = oralloy, region = -box)

# %%
root_universe = openmc.Universe()
root_universe.add_cell(mat_cell)
model.geometry = openmc.Geometry(root_universe)

# %%
bounds = [-10, -10, -10, 10, 10, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:])
energy_dist = openmc.stats.Uniform(a=0.0e6,b=20.0e6)
source = openmc.IndependentSource(space=uniform_dist, energy=energy_dist)

# %%
batches = 500
inactive = 20
particles = 10000

# Instantiate a Settings object
settings = openmc.Settings()

settings.source = source
settings.batches = batches
settings.inactive = inactive
settings.particles = particles
settings.run_mode = 'eigenvalue'

my_path = oralloy.name
settings.output = {'tallies': False, 'path':my_path}

model.settings = settings

# %%
groups = openmc.mgxs.EnergyGroups(group_edges='VITAMIN-J-42')
print(groups.group_edges)
# Out:
# [1.00e+03 1.00e+04 2.00e+04 3.00e+04 4.50e+04 6.00e+04 7.00e+04 7.50e+04
#  1.00e+05 1.50e+05 2.00e+05 3.00e+05 4.00e+05 4.50e+05 5.10e+05 5.12e+05
#  6.00e+05 7.00e+05 8.00e+05 1.00e+06 1.33e+06 1.34e+06 1.50e+06 1.66e+06
#  2.00e+06 2.50e+06 3.00e+06 3.50e+06 4.00e+06 4.50e+06 5.00e+06 5.50e+06
#  6.00e+06 6.50e+06 7.00e+06 7.50e+06 8.00e+06 1.00e+07 1.20e+07 1.40e+07
#  2.00e+07 3.00e+07 5.00e+07]

# %%
lanl30_edges= [
    1.00e-5,  # Thermal cutoff (lower bound)
    1.00e+0, 5.00e+0, 1.00e+1, 5.00e+1, 1.00e+2, 3.00e+2, 5.00e+2, 1.00e+3, 2.00e+3,
    3.00e+3, 5.00e+3, 1.00e+4, 2.00e+4, 3.00e+4, 5.00e+4, 8.00e+4, 1.00e+5, 1.50e+5,
    2.00e+5, 3.00e+5, 4.00e+5, 6.00e+5, 8.00e+5, 1.00e+6, 1.50e+6, 2.00e+6, 3.00e+6,
    5.00e+6, 1.00e+7, 2.00e+7  # Upper bound (fast neutrons)
]
groups = openmc.mgxs.EnergyGroups(group_edges=lanl30_edges)
print(groups.group_edges)
# Out:
# [1.0e-05 1.0e+00 5.0e+00 1.0e+01 5.0e+01 1.0e+02 3.0e+02 5.0e+02 1.0e+03
#  2.0e+03 3.0e+03 5.0e+03 1.0e+04 2.0e+04 3.0e+04 5.0e+04 8.0e+04 1.0e+05
#  1.5e+05 2.0e+05 3.0e+05 4.0e+05 6.0e+05 8.0e+05 1.0e+06 1.5e+06 2.0e+06
#  3.0e+06 5.0e+06 1.0e+07 2.0e+07]

# %%
# Initialize MGXS Library
mgxs_lib = openmc.mgxs.Library(model.geometry)

# Add the chosen group structure
mgxs_lib.energy_groups = groups

# Scatttering Format and Legendre Order
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3

# Specify multi-group cross-section types to compute
mgxs_lib.mgxs_types = ['total', 'absorption', 'scatter', 'fission', 'nu-fission', 'chi', 'reduced absorption', 'scatter matrix', 'nu-scatter matrix',\
                       'consistent nu-scatter matrix', 'multiplicity matrix']

# set uncertainty goal
mgxs_lib.tally_trigger = openmc.Trigger('std_dev', 1e-4)

# Compute cross sections on a nuclide-by-nuclide basis
mgxs_lib.by_nuclide = False

# Specify a "cell" domain type for the cross section tally filters
mgxs_lib.domain_type = 'material'

# Specify the cell domains over which to compute multi-group cross sections
mgxs_lib.domains = model.materials

# Construct all tallies needed for the multi-group cross section library
mgxs_lib.build_library()

tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies
# Out:
# /home/jae123p/miniconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %%
 model.export_to_model_xml(path = my_path + '/' + mat_cell.name + '.xml')
# Out:
# /home/jae123p/miniconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=104.
#   warn(msg, IDWarning)
# /home/jae123p/miniconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=105.
#   warn(msg, IDWarning)
# /home/jae123p/miniconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=115.
#   warn(msg, IDWarning)

# %%
sp_file = model.run()
# Out:
# [LAPTOP-H8MU6HJU:04709] shmem: mmap: an error occurred while determining whether or not /tmp/ompi.LAPTOP-H8MU6HJU.1000/jf.0/2859663360/shared_mem_cuda_pool.LAPTOP-H8MU6HJU could be created.
# [LAPTOP-H8MU6HJU:04709] create_and_attach: unable to create shared memory BTL coordinating structure :: size 134217728
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2024 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.0
#         Git SHA1 | 84fb85977f46e162fea8f5a20ea653a3ec62ac24
#        Date/Time | 2025-05-05 06:40:37
#    MPI Processes | 1
#   OpenMP Threads | 24
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading U234 from /home/jae123p/endfb80/endfb-viii.0-hdf5/neutron/U234.h5
#  Reading U235 from /home/jae123p/endfb80/endfb-viii.0-hdf5/neutron/U235.h5
#  Reading U238 from /home/jae123p/endfb80/endfb-viii.0-hdf5/neutron/U238.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 30000000 eV for U234
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created in
#
#          WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#     this generation will not be banked. Results may be non-deterministic.
#       this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#        WARNING:     this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic. WARNING:  The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#         this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#            WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic. WARNING: this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
#  WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#     WARNING: The shared fission bank is full. Additional fission sites created in
#     WARNING:               this generation will not be banked. Results may be non-deterministic.
#     this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING:  The shared fission bank is full. Additional fission sites created in
#                  this generation will not be banked. Results may be non-deterministic.
#  WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#         WARNING:   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic. WARNING:
#  WARNING: The shared fission bank is full. Additional fission sites created in
#   The shared fission bank is full. Additional fission sites created in
#
#  WARNING:           WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in  WARNING:
#
#           WARNING:  The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#        WARNING:    The shared fission bank is full. Additional fission sites created in WARNING: The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic.
#    this generation will not be banked. Results may be non-deterministic.
#
#        The shared fission bank is full. Additional fission sites created in WARNING:   WARNING: The shared fission bank is full. Additional fission sites created in
#         WARNING: The shared fission bank is full. Additional fission sites created in
#        this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic.
#             The shared fission bank is full. Additional fission sites created in WARNING:   The shared fission bank is full. Additional fission sites created in
#
#
#
# this generation will not be banked. Results may be non-deterministic.
#             this generation will not be banked. Results may be non-deterministic.
#
#   this generation will not be banked. Results may be non-deterministic.    WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in    this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in
#              this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#
#  WARNING:  The shared fission bank is full. Additional fission sites created in this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  this generation will not be banked. Results may be non-deterministic.
#  WARNING:
#     WARNING: The shared fission bank is full. Additional fission sites created in
#
#  WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#
#
#  The shared fission bank is full. Additional fission sites created in
#              this generation will not be banked. Results may be non-deterministic. WARNING:
#  WARNING: The shared fission bank is full. Additional fission sites created in
#     WARNING:  The shared fission bank is full. Additional fission sites created in The shared fission bank is full. Additional fission sites created in    WARNING:
#           this generation will not be banked. Results may be non-deterministic.
#         this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#      WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#      The shared fission bank is full. Additional fission sites created in WARNING: this generation will not be banked. Results may be non-deterministic.   The shared fission bank is full. Additional fission sites created in          this generation will not be banked. Results may be non-deterministic.
#
#    WARNING:
#  WARNING: The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in
#                             this generation will not be banked. Results may be non-deterministic.
#     this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.   this generation will not be banked. Results may be non-deterministic.
#
#
#
# this generation will not be banked. Results may be non-deterministic.
#   this generation will not be banked. Results may be non-deterministic. WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#        this generation will not be banked. Results may be non-deterministic.
#      WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
#            this generation will not be banked. Results may be non-deterministic.
#      WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#    WARNING: this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in    this generation will not be banked. Results may be non-deterministic. WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#
# The shared fission bank is full. Additional fission sites created in
#
#  WARNING:  WARNING:
#     The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#   this generation will not be banked. Results may be non-deterministic.      this generation will not be banked. Results may be non-deterministic.      this generation will not be banked. Results may be non-deterministic.
#          this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in  WARNING:
# The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#
#
#          WARNING:    this generation will not be banked. Results may be non-deterministic.
#  WARNING:    The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#    this generation will not be banked. Results may be non-deterministic. WARNING:  WARNING:
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
#         this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
#   WARNING: this generation will not be banked. Results may be non-deterministic. The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#                  The shared fission bank is full. Additional fission sites created in WARNING:
#          this generation will not be banked. Results may be non-deterministic.
#
#     The shared fission bank is full. Additional fission sites created in  WARNING:
# this generation will not be banked. Results may be non-deterministic.       this generation will not be banked. Results may be non-deterministic.
#     WARNING:   WARNING:
# The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in WARNING: The shared fission bank is full. Additional fission sites created in WARNING:
#   this generation will not be banked. Results may be non-deterministic.
#     The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#
#
# this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in   WARNING: The shared fission bank is full. Additional fission sites created in
#         this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
#    this generation will not be banked. Results may be non-deterministic.
#  WARNING:  WARNING: this generation will not be banked. Results may be non-deterministic.
#   WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in           The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in   this generation will not be banked. Results may be non-deterministic.
#     The shared fission bank is full. Additional fission sites created in          this generation will not be banked. Results may be non-deterministic.
#  WARNING:
# The shared fission bank is full. Additional fission sites created in
#
#    WARNING: The shared fission bank is full. Additional fission sites created in
#
#
#  WARNING:   this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.
#
#  WARNING:
#       this generation will not be banked. Results may be non-deterministic.     this generation will not be banked. Results may be non-deterministic.
#   WARNING:     WARNING:
#  this generation will not be banked. Results may be non-deterministic.
#  The shared fission bank is full. Additional fission sites created in
#           The shared fission bank is full. Additional fission sites created in
#   The shared fission bank is full. Additional fission sites created in        this generation will not be banked. Results may be non-deterministic.   WARNING: The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#   WARNING: The shared fission bank is full. Additional fission sites created in
#         WARNING: this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in
#
#
#
#  this generation will not be banked. Results may be non-deterministic.
#
#        WARNING:
#      this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.  WARNING:            this generation will not be banked. Results may be non-deterministic.
#  WARNING:  WARNING: The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#   WARNING: The shared fission bank is full. Additional fission sites created in
#
# The shared fission bank is full. Additional fission sites created in
#   The shared fission bank is full. Additional fission sites created in WARNING:
#  WARNING:  this generation will not be banked. Results may be non-deterministic.
#            this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#
#  this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#       WARNING:       this generation will not be banked. Results may be non-deterministic.      The shared fission bank is full. Additional fission sites created in WARNING:   The shared fission bank is full. Additional fission sites created in   The shared fission bank is full. Additional fission sites created in
#
#     this generation will not be banked. Results may be non-deterministic.   WARNING:
#
#  WARNING: The shared fission bank is full. Additional fission sites created in  WARNING:
#      The shared fission bank is full. Additional fission sites created in
#
#     The shared fission bank is full. Additional fission sites created in       WARNING:            this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#
#
#  WARNING:   WARNING:     this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#          this generation will not be banked. Results may be non-deterministic.     WARNING:   WARNING: The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#    this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#               this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
#  WARNING:  WARNING:         The shared fission bank is full. Additional fission sites created in
#   The shared fission bank is full. Additional fission sites created in
#            this generation will not be banked. Results may be non-deterministic.
#   The shared fission bank is full. Additional fission sites created in WARNING: The shared fission bank is full. Additional fission sites created in
#
# this generation will not be banked. Results may be non-deterministic.  this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#          WARNING:          The shared fission bank is full. Additional fission sites created in
#      this generation will not be banked. Results may be non-deterministic.         this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.   WARNING:
#      The shared fission bank is full. Additional fission sites created in
#
#           this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#    this generation will not be banked. Results may be non-deterministic.
#
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#   The shared fission bank is full. Additional fission sites created in
#      WARNING:       this generation will not be banked. Results may be non-deterministic.
#            WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#  this generation will not be banked. Results may be non-deterministic. WARNING:
# this generation will not be banked. Results may be non-deterministic.   The shared fission bank is full. Additional fission sites created in WARNING:
# The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
#     this generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created in
#    The shared fission bank is full. Additional fission sites created in
#         The shared fission bank is full. Additional fission sites created in
#
# this generation will not be banked. Results may be non-deterministic.    this generation will not be banked. Results may be non-deterministic.   this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#  WARNING:         this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#        WARNING: The shared fission bank is full. Additional fission sites created in
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
#
#  this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#
#  WARNING:
#   WARNING:            The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic.
#   WARNING:           WARNING: The shared fission bank is full. Additional fission sites created in
#           WARNING:  WARNING: The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#
#
#           this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
#           WARNING:
#         this generation will not be banked. Results may be non-deterministic.
#  WARNING:
#
#     WARNING:           The shared fission bank is full. Additional fission sites created in  The shared fission bank is full. Additional fission sites created in    WARNING:   The shared fission bank is full. Additional fission sites created in  this generation will not be banked. Results may be non-deterministic.
#
# The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.    this generation will not be banked. Results may be non-deterministic.
#
#
#      this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
#
# this generation will not be banked. Results may be non-deterministic.      WARNING:
# The shared fission bank is full. Additional fission sites created in
#    this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING:        WARNING:  The shared fission bank is full. Additional fission sites created in WARNING:
#           The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in WARNING: The shared fission bank is full. Additional fission sites created in
#
# The shared fission bank is full. Additional fission sites created in
#
#       WARNING:
#     this generation will not be banked. Results may be non-deterministic.
#         WARNING:  WARNING:   The shared fission bank is full. Additional fission sites created in  The shared fission bank is full. Additional fission sites created in
#       this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#             this generation will not be banked. Results may be non-deterministic.
#   WARNING:         this generation will not be banked. Results may be non-deterministic.
#      The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.    WARNING:   The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.
#
#                this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#             this generation will not be banked. Results may be non-deterministic.  WARNING:
#           this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#  WARNING: this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#      The shared fission bank is full. Additional fission sites created in    this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.
#
#           this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#            WARNING: The shared fission bank is full. Additional fission sites created in
#   The shared fission bank is full. Additional fission sites created in
#
#          this generation will not be banked. Results may be non-deterministic. WARNING:  The shared fission bank is full. Additional fission sites created in
#              this generation will not be banked. Results may be non-deterministic. WARNING:
#         this generation will not be banked. Results may be non-deterministic.
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#   WARNING:       The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic. The shared fission bank is full. Additional fission sites created in
#            WARNING:
#      this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
#  this generation will not be banked. Results may be non-deterministic.
#     WARNING:  WARNING:  The shared fission bank is full. Additional fission sites created in
#  The shared fission bank is full. Additional fission sites created in
#  WARNING:
#
# The shared fission bank is full. Additional fission sites created in
#             The shared fission bank is full. Additional fission sites created in    this generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created in  The shared fission bank is full. Additional fission sites created in this generation will not be banked. Results may be non-deterministic.
#   this generation will not be banked. Results may be non-deterministic.   WARNING:
#               this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
# this generation will not be banked. Results may be non-deterministic.  this generation will not be banked. Results may be non-deterministic.
#
#   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#          WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING: The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in
#
#      this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#  this generation will not be banked. Results may be non-deterministic.
#       WARNING: The shared fission bank is full. Additional fission sites created in
#         this generation will not be banked. Results may be non-deterministic.
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#   WARNING:   WARNING:      this generation will not be banked. Results may be non-deterministic.
#   this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#
#           WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING: The shared fission bank is full. Additional fission sites created in
#                   this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#
#
#      this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
#           this generation will not be banked. Results may be non-deterministic.
#
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#          WARNING: this generation will not be banked. Results may be non-deterministic.   WARNING: The shared fission bank is full. Additional fission sites created in
#          this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in
#                  WARNING:
#  WARNING:       WARNING:      The shared fission bank is full. Additional fission sites created in   this generation will not be banked. Results may be non-deterministic.
#
#      WARNING:       this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#                 this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#  this generation will not be banked. Results may be non-deterministic.    WARNING: The shared fission bank is full. Additional fission sites created in
#
#       WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#    this generation will not be banked. Results may be non-deterministic.
#  WARNING:  this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in   this generation will not be banked. Results may be non-deterministic.  The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in     WARNING: The shared fission bank is full. Additional fission sites created in
#   this generation will not be banked. Results may be non-deterministic.
#   WARNING:   WARNING:    this generation will not be banked. Results may be non-deterministic.
#
#    WARNING: The shared fission bank is full. Additional fission sites created in
#    The shared fission bank is full. Additional fission sites created in
#
#    The shared fission bank is full. Additional fission sites created in   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#              this generation will not be banked. Results may be non-deterministic.
#        WARNING:       this generation will not be banked. Results may be non-deterministic.
#             this generation will not be banked. Results may be non-deterministic.
#  WARNING:   this generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in
#
#         WARNING:  WARNING:  WARNING:       this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#
#   The shared fission bank is full. Additional fission sites created in
#       this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#
#   WARNING: The shared fission bank is full. Additional fission sites created in
#
#  this generation will not be banked. Results may be non-deterministic.
#      this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#       468/1    2.28254    2.26475 +/- 0.00102
#       469/1    2.24287    2.26471 +/- 0.00102
#       470/1    2.27771    2.26473 +/- 0.00102
#       471/1    2.24706    2.26470 +/- 0.00102
#       472/1    2.27230    2.26471 +/- 0.00102
#       473/1    2.27400    2.26473 +/- 0.00101
#       474/1    2.28529    2.26478 +/- 0.00101
#       475/1    2.26993    2.26479 +/- 0.00101
#       476/1    2.28575    2.26484 +/- 0.00101
#       477/1    2.25318    2.26481 +/- 0.00101
#       478/1    2.26096    2.26480 +/- 0.00100
#       479/1    2.24040    2.26475 +/- 0.00100
#       480/1    2.24408    2.26470 +/- 0.00100
#       481/1    2.23187    2.26463 +/- 0.00100
#       482/1    2.27558    2.26466 +/- 0.00100
#       483/1    2.28920    2.26471 +/- 0.00100
#       484/1    2.26602    2.26471 +/- 0.00100
#       485/1    2.26849    2.26472 +/- 0.00100
#       486/1    2.25922    2.26471 +/- 0.00099
#       487/1    2.27023    2.26472 +/- 0.00099
#       488/1    2.28486    2.26476 +/- 0.00099
#       489/1    2.25601    2.26474 +/- 0.00099
#       490/1    2.29370    2.26481 +/- 0.00099
#       491/1    2.24923    2.26477 +/- 0.00099
#       492/1    2.27751    2.26480 +/- 0.00099
#       493/1    2.26736    2.26481 +/- 0.00098
#       494/1    2.29374    2.26487 +/- 0.00098
#       495/1    2.27963    2.26490 +/- 0.00098
#       496/1    2.28856    2.26495 +/- 0.00098
#       497/1    2.29089    2.26500 +/- 0.00098
#       498/1    2.27222    2.26502 +/- 0.00098
#       499/1    2.21801    2.26492 +/- 0.00098
#       500/1    2.25626    2.26490 +/- 0.00098
#  Creating state point Oralloy/statepoint.500.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.7494e-01 seconds
#    Reading cross sections          = 4.4125e-01 seconds
#  Total time in simulation          = 1.3550e+01 seconds
#    Time in transport only          = 7.1000e+00 seconds
#    Time in inactive batches        = 3.3984e-01 seconds
#    Time in active batches          = 1.3210e+01 seconds
#    Time synchronizing fission bank = 3.1299e-01 seconds
#      Sampling source sites         = 2.6591e-01 seconds
#      SEND/RECV source sites        = 4.4958e-02 seconds
#    Time accumulating tallies       = 5.9590e+00 seconds
#    Time writing statepoints        = 1.0812e-02 seconds
#  Total time for finalization       = 4.5260e-06 seconds
#  Total time elapsed                = 1.4038e+01 seconds
#  Calculation Rate (inactive)       = 588506 particles/second
#  Calculation Rate (active)         = 363349 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 2.26443 +/- 0.00089
#  k-effective (Track-length)  = 2.26490 +/- 0.00098
#  k-effective (Absorption)    = 2.26350 +/- 0.00017
#  Combined k-effective        = 2.26358 +/- 0.00015
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# Load the last statepoint file
sp = openmc.StatePoint(sp_file)

# %%
# Initialize MGXS Library with OpenMC statepoint data
mgxs_lib.load_from_statepoint(sp)

# %%
mgxs_file = mgxs_lib.create_mg_library(xs_type = 'macro')
mgxs_file.export_to_hdf5(filename = 'HEU-MET-Fast-003-1/oralloy.h5')

# %%
sp.close()
