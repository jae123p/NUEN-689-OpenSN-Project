# %%
import openmc
import openmc.mgxs
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas
import h5py
# %matplotlib inline

# %%
import os

# %%
os.environ['PATH'] += r':/home/jae123p/miniconda3/envs/openmc-env/bin'

# %env OPENMC_CROSS_SECTIONS=/home/jae123p/endfb80/endfb-viii.0-hdf5/cross_sections.xml
# Out:
# env: OPENMC_CROSS_SECTIONS=/home/jae123p/endfb80/endfb-viii.0-hdf5/cross_sections.xml

# %%
model = openmc.Model()

# %%
oralloy = openmc.Material(name="Oralloy")
oralloy.add_nuclide('U234', 4.9210e-04)
oralloy.add_nuclide('U235', 4.4917e-02)
oralloy.add_nuclide('U238', 2.5993e-03)

materials = openmc.Materials([oralloy])

# %%
model.materials = openmc.Materials([oralloy])

# %%
box = openmc.model.RectangularPrism(width=10, height = 10, boundary_type='reflective')
mat_cell = openmc.Cell(name='OralloyCell', fill = oralloy, region = -box)

# %%
root_universe = openmc.Universe()
root_universe.add_cell(mat_cell)
model.geometry = openmc.Geometry(root_universe)

# %%
bounds = [-10, -10, -10, 10, 10, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:])
energy_dist = openmc.stats.Uniform(a=0.0e6,b=20.0e6)
source = openmc.IndependentSource(space=uniform_dist, energy=energy_dist)

# %%
batches = 500
inactive = 20
particles = 10000

# Instantiate a Settings object
settings = openmc.Settings()

settings.source = source
settings.batches = batches
settings.inactive = inactive
settings.particles = particles
settings.run_mode = 'eigenvalue'

my_path = oralloy.name
settings.output = {'tallies': False, 'path':my_path}

model.settings = settings

# %%
lanl30_edges= [
    1.00e-5,  # Thermal cutoff (lower bound)
    1.00e+0, 5.00e+0, 1.00e+1, 5.00e+1, 1.00e+2, 3.00e+2, 5.00e+2, 1.00e+3, 2.00e+3,
    3.00e+3, 5.00e+3, 1.00e+4, 2.00e+4, 3.00e+4, 5.00e+4, 8.00e+4, 1.00e+5, 1.50e+5,
    2.00e+5, 3.00e+5, 4.00e+5, 6.00e+5, 8.00e+5, 1.00e+6, 1.50e+6, 2.00e+6, 3.00e+6,
    5.00e+6, 1.00e+7, 2.00e+7  # Upper bound (fast neutrons)
]

groups = openmc.mgxs.EnergyGroups(group_edges=lanl30_edges)

# %%
# Initialize MGXS Library
mgxs_lib = openmc.mgxs.Library(model.geometry)

# Add the chosen group structure
mgxs_lib.energy_groups = groups

# Scatttering Format and Legendre Order
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3

# Specify multi-group cross-section types to compute
mgxs_lib.mgxs_types = ['total', 'absorption', 'scatter', 'fission', 'nu-fission', 'chi', 'reduced absorption', 'scatter matrix', 'nu-scatter matrix',\
                       'consistent nu-scatter matrix', 'multiplicity matrix']

# set uncertainty goal
mgxs_lib.tally_trigger = openmc.Trigger('std_dev', 1e-4)

# Compute cross sections on a nuclide-by-nuclide basis
mgxs_lib.by_nuclide = False

# Specify a "cell" domain type for the cross section tally filters
mgxs_lib.domain_type = 'material'

# Specify the cell domains over which to compute multi-group cross sections
mgxs_lib.domains = model.materials

# Construct all tallies needed for the multi-group cross section library
mgxs_lib.build_library()

tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies
# Out:
# /home/jae123p/miniconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %%
 model.export_to_model_xml(path = my_path + '/' + mat_cell.name + '.xml')
# Out:
# /home/jae123p/miniconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/jae123p/miniconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=2.
#   warn(msg, IDWarning)
# /home/jae123p/miniconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=12.
#   warn(msg, IDWarning)

# %%
sp_file = model.run()
# Out:
# [LAPTOP-H8MU6HJU:08379] shmem: mmap: an error occurred while determining whether or not /tmp/ompi.LAPTOP-H8MU6HJU.1000/jf.0/520486912/shared_mem_cuda_pool.LAPTOP-H8MU6HJU could be created.
# [LAPTOP-H8MU6HJU:08379] create_and_attach: unable to create shared memory BTL coordinating structure :: size 134217728
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2024 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.0
#         Git SHA1 | 84fb85977f46e162fea8f5a20ea653a3ec62ac24
#        Date/Time | 2025-05-05 16:36:15
#    MPI Processes | 1
#   OpenMP Threads | 24
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading U234 from /home/jae123p/endfb80/endfb-viii.0-hdf5/neutron/U234.h5
#  Reading U235 from /home/jae123p/endfb80/endfb-viii.0-hdf5/neutron/U235.h5
#  Reading U238 from /home/jae123p/endfb80/endfb-viii.0-hdf5/neutron/U238.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 30000000 eV for U234
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in WARNING: The shared fission bank is full. Additional fission sites created in WARNING: The shared fission bank is full. Additional fission sites created in
#
#
#  WARNING:           this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#
#           this generation will not be banked. Results may be non-deterministic. WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in
#
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#            WARNING: The shared fission bank is full. Additional fission sites created in
#  this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic. WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#
# The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#   WARNING:     this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in WARNING: The shared fission bank is full. Additional fission sites created in
#       WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING:      this generation will not be banked. Results may be non-deterministic.
#  WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#               WARNING:   The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in   this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#          WARNING:    WARNING:
#  The shared fission bank is full. Additional fission sites created in
#  this generation will not be banked. Results may be non-deterministic.
#             WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#      this generation will not be banked. Results may be non-deterministic.   WARNING: The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic.
#  WARNING:  WARNING:    WARNING: The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in WARNING: this generation will not be banked. Results may be non-deterministic.
#
#  WARNING: The shared fission bank is full. Additional fission sites created in WARNING:
#   WARNING: The shared fission bank is full. Additional fission sites created in WARNING:  The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in WARNING:  The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#       WARNING:
#           WARNING:
#         WARNING:        this generation will not be banked. Results may be non-deterministic.
#  The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.  WARNING: The shared fission bank is full. Additional fission sites created in
#
#
#  The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#
#
#             The shared fission bank is full. Additional fission sites created in
#            WARNING: The shared fission bank is full. Additional fission sites created in
#
#           WARNING:
#
#                  this generation will not be banked. Results may be non-deterministic.
#
#      this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic. WARNING:       this generation will not be banked. Results may be non-deterministic.
#
#
#  WARNING:   this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in
#
#
#
#    this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in WARNING:   WARNING: The shared fission bank is full. Additional fission sites created in WARNING: The shared fission bank is full. Additional fission sites created in   The shared fission bank is full. Additional fission sites created in
#
#   WARNING: The shared fission bank is full. Additional fission sites created in
#            this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in       this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
#
#
#  this generation will not be banked. Results may be non-deterministic.
#   WARNING:    WARNING:    WARNING:     The shared fission bank is full. Additional fission sites created in
#
#   this generation will not be banked. Results may be non-deterministic.
#   The shared fission bank is full. Additional fission sites created in
#          WARNING:
#    WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#   The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.
#  this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.    WARNING:
#
#    WARNING:  WARNING:    WARNING:   The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in The shared fission bank is full. Additional fission sites created in
#  The shared fission bank is full. Additional fission sites created in
#    WARNING:
#
#   this generation will not be banked. Results may be non-deterministic.   this generation will not be banked. Results may be non-deterministic.
#
#  WARNING: The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in  WARNING:   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#         WARNING:
# this generation will not be banked. Results may be non-deterministic.
#   WARNING:
#       The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in this generation will not be banked. Results may be non-deterministic.
#
#
#       this generation will not be banked. Results may be non-deterministic.
#
#          The shared fission bank is full. Additional fission sites created in WARNING:
#          this generation will not be banked. Results may be non-deterministic.
#      WARNING:                  this generation will not be banked. Results may be non-deterministic.
#      this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic. WARNING:
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#         The shared fission bank is full. Additional fission sites created in
#  The shared fission bank is full. Additional fission sites created in                            this generation will not be banked. Results may be non-deterministic.       this generation will not be banked. Results may be non-deterministic.    this generation will not be banked. Results may be non-deterministic.
#  this generation will not be banked. Results may be non-deterministic.  WARNING:       The shared fission bank is full. Additional fission sites created in The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#      WARNING:  WARNING:
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#      The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#            this generation will not be banked. Results may be non-deterministic.
#
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING:
#               WARNING:  The shared fission bank is full. Additional fission sites created in   WARNING:  The shared fission bank is full. Additional fission sites created in
#  this generation will not be banked. Results may be non-deterministic.
#       WARNING:
#   this generation will not be banked. Results may be non-deterministic.
#   this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in   this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in this generation will not be banked. Results may be non-deterministic.
#
# The shared fission bank is full. Additional fission sites created in   WARNING: The shared fission bank is full. Additional fission sites created in
#
#         this generation will not be banked. Results may be non-deterministic.
#      WARNING: this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic. WARNING:
#   WARNING:  The shared fission bank is full. Additional fission sites created in
#
# this generation will not be banked. Results may be non-deterministic.
#
#  The shared fission bank is full. Additional fission sites created in
#  this generation will not be banked. Results may be non-deterministic.
#
#       WARNING: The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in  WARNING:
#   WARNING:  this generation will not be banked. Results may be non-deterministic. WARNING:
#   WARNING:     this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in  WARNING:
#               The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic.
#
#
#
#     The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING:     WARNING:   The shared fission bank is full. Additional fission sites created in  WARNING:  WARNING:       WARNING:   this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#
#
#      this generation will not be banked. Results may be non-deterministic.     The shared fission bank is full. Additional fission sites created in
#   WARNING:          The shared fission bank is full. Additional fission sites created in           this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#      this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
#      this generation will not be banked. Results may be non-deterministic.  this generation will not be banked. Results may be non-deterministic.
#   WARNING:  The shared fission bank is full. Additional fission sites created in
#            this generation will not be banked. Results may be non-deterministic. WARNING:      The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.
#
#           this generation will not be banked. Results may be non-deterministic. The shared fission bank is full. Additional fission sites created in WARNING:
#
#  WARNING:         WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#
# this generation will not be banked. Results may be non-deterministic. WARNING:   WARNING:  this generation will not be banked. Results may be non-deterministic.   this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in  The shared fission bank is full. Additional fission sites created in
#     The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#       this generation will not be banked. Results may be non-deterministic.
#          WARNING:
#    WARNING:
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
#           this generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created in
#       The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.
#
# this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in
#     The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic.
#  WARNING:
#
#
#  The shared fission bank is full. Additional fission sites created in
#      this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.       this generation will not be banked. Results may be non-deterministic. WARNING:  WARNING: this generation will not be banked. Results may be non-deterministic.  The shared fission bank is full. Additional fission sites created in
#
#
#
#       WARNING:   The shared fission bank is full. Additional fission sites created in
#  The shared fission bank is full. Additional fission sites created in  this generation will not be banked. Results may be non-deterministic.
#           The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#   WARNING:  WARNING:
#   The shared fission bank is full. Additional fission sites created in
#
# The shared fission bank is full. Additional fission sites created in
#   WARNING:      WARNING: The shared fission bank is full. Additional fission sites created in   WARNING:
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING:  WARNING:
# The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#    WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING:  The shared fission bank is full. Additional fission sites created in   this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created in
#
#
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#
#  WARNING: The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#       this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#   WARNING: The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#   The shared fission bank is full. Additional fission sites created in
#     The shared fission bank is full. Additional fission sites created in  WARNING:    WARNING:        this generation will not be banked. Results may be non-deterministic.
#  The shared fission bank is full. Additional fission sites created in    this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#
#  WARNING:
#        The shared fission bank is full. Additional fission sites created in
#    WARNING:    WARNING: The shared fission bank is full. Additional fission sites created in
#             The shared fission bank is full. Additional fission sites created in           this generation will not be banked. Results may be non-deterministic.         this generation will not be banked. Results may be non-deterministic.
#  this generation will not be banked. Results may be non-deterministic.
#       WARNING:   this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#
#    WARNING:     WARNING: The shared fission bank is full. Additional fission sites created in
#            The shared fission bank is full. Additional fission sites created in
#        WARNING:         WARNING:  this generation will not be banked. Results may be non-deterministic.   this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.  this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#
#
#
# this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in    WARNING:   WARNING:
#    this generation will not be banked. Results may be non-deterministic.       WARNING:  WARNING:      The shared fission bank is full. Additional fission sites created in The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in   WARNING: The shared fission bank is full. Additional fission sites created in  this generation will not be banked. Results may be non-deterministic.
#  this generation will not be banked. Results may be non-deterministic.
#
#   WARNING:  The shared fission bank is full. Additional fission sites created in The shared fission bank is full. Additional fission sites created in
#  The shared fission bank is full. Additional fission sites created in
#       this generation will not be banked. Results may be non-deterministic.
#       this generation will not be banked. Results may be non-deterministic.
#         The shared fission bank is full. Additional fission sites created in WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#
#
#
#
#     WARNING:     this generation will not be banked. Results may be non-deterministic.
#
#  this generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created in
#
#   The shared fission bank is full. Additional fission sites created in    The shared fission bank is full. Additional fission sites created in
#    this generation will not be banked. Results may be non-deterministic.  this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.
#   WARNING:
# The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in
#
#             this generation will not be banked. Results may be non-deterministic.
#          this generation will not be banked. Results may be non-deterministic.
#            WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#     this generation will not be banked. Results may be non-deterministic. WARNING: this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.   WARNING:   this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#
#       this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#    WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#  WARNING:
#        this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#         The shared fission bank is full. Additional fission sites created in
#                WARNING:
#  this generation will not be banked. Results may be non-deterministic.
#
#    WARNING: The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.   WARNING: The shared fission bank is full. Additional fission sites created in
#
#
#  WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING:   this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING:  The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#       this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#    WARNING:       this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING:  WARNING:   The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#    WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#                this generation will not be banked. Results may be non-deterministic.        The shared fission bank is full. Additional fission sites created in
#   this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created in
#           The shared fission bank is full. Additional fission sites created in
#
#
# this generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created in WARNING: The shared fission bank is full. Additional fission sites created in
#
# The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#         The shared fission bank is full. Additional fission sites created in
#  WARNING:
#    WARNING: The shared fission bank is full. Additional fission sites created in
#    The shared fission bank is full. Additional fission sites created in           WARNING:
# this generation will not be banked. Results may be non-deterministic. The shared fission bank is full. Additional fission sites created in    The shared fission bank is full. Additional fission sites created in
# this generation will not be banked. Results may be non-deterministic.
#                  WARNING:
#
#   this generation will not be banked. Results may be non-deterministic.
#
#     WARNING:    The shared fission bank is full. Additional fission sites created in
#  WARNING:               this generation will not be banked. Results may be non-deterministic.
#  The shared fission bank is full. Additional fission sites created in
#
#    WARNING:    WARNING:     this generation will not be banked. Results may be non-deterministic.
#      this generation will not be banked. Results may be non-deterministic. The shared fission bank is full. Additional fission sites created in The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.  this generation will not be banked. Results may be non-deterministic. The shared fission bank is full. Additional fission sites created in
#  WARNING: The shared fission bank is full. Additional fission sites created in
#             this generation will not be banked. Results may be non-deterministic.
#    WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#        this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
#  WARNING: this generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#  WARNING:  WARNING:  The shared fission bank is full. Additional fission sites created in
#   The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: this generation will not be banked. Results may be non-deterministic.
# this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#          WARNING:   WARNING:   The shared fission bank is full. Additional fission sites created in   this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in                        this generation will not be banked. Results may be non-deterministic.
#
#           this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic. WARNING:
#    The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#  WARNING:         this generation will not be banked. Results may be non-deterministic.
#
#     WARNING: this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#     WARNING:   The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#              WARNING:    The shared fission bank is full. Additional fission sites created in The shared fission bank is full. Additional fission sites created in
#
#
#         this generation will not be banked. Results may be non-deterministic.
#    The shared fission bank is full. Additional fission sites created in     WARNING:      The shared fission bank is full. Additional fission sites created in    this generation will not be banked. Results may be non-deterministic. WARNING: The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.        this generation will not be banked. Results may be non-deterministic.
#
#
#
#
#
#
#  WARNING:
#     WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.   WARNING:
# The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.
#
#
#       this generation will not be banked. Results may be non-deterministic.
#     WARNING: this generation will not be banked. Results may be non-deterministic.      WARNING: this generation will not be banked. Results may be non-deterministic.  this generation will not be banked. Results may be non-deterministic. The shared fission bank is full. Additional fission sites created in
#
#          The shared fission bank is full. Additional fission sites created in    this generation will not be banked. Results may be non-deterministic.      WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING:   this generation will not be banked. Results may be non-deterministic.
#        this generation will not be banked. Results may be non-deterministic.
#
#
#
#
#  WARNING:   WARNING: The shared fission bank is full. Additional fission sites created in
#            WARNING: The shared fission bank is full. Additional fission sites created in
#    WARNING:    WARNING:   this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
#
#
#   The shared fission bank is full. Additional fission sites created in
#                   WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#   WARNING:    this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.
#     The shared fission bank is full. Additional fission sites created in    this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic.The shared fission bank is full. Additional fission sites created in  The shared fission bank is full. Additional fission sites created in        this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING:     this generation will not be banked. Results may be non-deterministic.
#
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#  WARNING:
#           this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#      WARNING:
# The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#   WARNING: The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in
#   The shared fission bank is full. Additional fission sites created in
#   WARNING:  this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in WARNING:
# The shared fission bank is full. Additional fission sites created in
# The shared fission bank is full. Additional fission sites created in
#
#  this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.
#
#         WARNING: The shared fission bank is full. Additional fission sites created in          WARNING: this generation will not be banked. Results may be non-deterministic.
#  WARNING:
#
#  WARNING:  The shared fission bank is full. Additional fission sites created in
#    this generation will not be banked. Results may be non-deterministic.
#  this generation will not be banked. Results may be non-deterministic. this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created inThe shared fission bank is full. Additional fission sites created in
#
#  WARNING:
#    WARNING:
#     this generation will not be banked. Results may be non-deterministic.
#   WARNING:      The shared fission bank is full. Additional fission sites created in The shared fission bank is full. Additional fission sites created in
#           this generation will not be banked. Results may be non-deterministic.
#
#    WARNING: this generation will not be banked. Results may be non-deterministic.
#  WARNING: The shared fission bank is full. Additional fission sites created in    The shared fission bank is full. Additional fission sites created in
#   WARNING:   The shared fission bank is full. Additional fission sites created in WARNING:          this generation will not be banked. Results may be non-deterministic.
# The shared fission bank is full. Additional fission sites created in
#
# The shared fission bank is full. Additional fission sites created in
#
# The shared fission bank is full. Additional fission sites created in           this generation will not be banked. Results may be non-deterministic.
#            WARNING: this generation will not be banked. Results may be non-deterministic.
#     WARNING: The shared fission bank is full. Additional fission sites created in WARNING:  WARNING: The shared fission bank is full. Additional fission sites created in
#
#   The shared fission bank is full. Additional fission sites created in   The shared fission bank is full. Additional fission sites created inthis generation will not be banked. Results may be non-deterministic.
#  this generation will not be banked. Results may be non-deterministic.
#   WARNING: this generation will not be banked. Results may be non-deterministic.
#  The shared fission bank is full. Additional fission sites created in
#  The shared fission bank is full. Additional fission sites created in
#              this generation will not be banked. Results may be non-deterministic.
#
#
#   WARNING:
#
#        this generation will not be banked. Results may be non-deterministic.this generation will not be banked. Results may be non-deterministic
#       467/1    2.27163    2.26579 +/- 0.00100
#       468/1    2.25011    2.26576 +/- 0.00100
#       469/1    2.25452    2.26573 +/- 0.00100
#       470/1    2.26653    2.26573 +/- 0.00100
#       471/1    2.29562    2.26580 +/- 0.00100
#       472/1    2.23041    2.26572 +/- 0.00100
#       473/1    2.30365    2.26581 +/- 0.00100
#       474/1    2.21849    2.26570 +/- 0.00100
#       475/1    2.23650    2.26564 +/- 0.00100
#       476/1    2.24686    2.26560 +/- 0.00100
#       477/1    2.26520    2.26560 +/- 0.00100
#       478/1    2.26996    2.26561 +/- 0.00100
#       479/1    2.28293    2.26564 +/- 0.00100
#       480/1    2.28726    2.26569 +/- 0.00099
#       481/1    2.26581    2.26569 +/- 0.00099
#       482/1    2.26546    2.26569 +/- 0.00099
#       483/1    2.30949    2.26578 +/- 0.00099
#       484/1    2.25753    2.26577 +/- 0.00099
#       485/1    2.26246    2.26576 +/- 0.00099
#       486/1    2.28472    2.26580 +/- 0.00099
#       487/1    2.27242    2.26581 +/- 0.00098
#       488/1    2.28703    2.26586 +/- 0.00098
#       489/1    2.24863    2.26582 +/- 0.00098
#       490/1    2.23414    2.26576 +/- 0.00098
#       491/1    2.28549    2.26580 +/- 0.00098
#       492/1    2.26819    2.26580 +/- 0.00098
#       493/1    2.24370    2.26576 +/- 0.00098
#       494/1    2.29813    2.26582 +/- 0.00098
#       495/1    2.27404    2.26584 +/- 0.00098
#       496/1    2.27737    2.26587 +/- 0.00097
#       497/1    2.25787    2.26585 +/- 0.00097
#       498/1    2.22960    2.26577 +/- 0.00097
#       499/1    2.27277    2.26579 +/- 0.00097
#       500/1    2.24752    2.26575 +/- 0.00097
#  Creating state point Oralloy/statepoint.500.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.6781e-01 seconds
#    Reading cross sections          = 4.4493e-01 seconds
#  Total time in simulation          = 9.4560e+00 seconds
#    Time in transport only          = 6.1377e+00 seconds
#    Time in inactive batches        = 2.8497e-01 seconds
#    Time in active batches          = 9.1711e+00 seconds
#    Time synchronizing fission bank = 3.2415e-01 seconds
#      Sampling source sites         = 2.8205e-01 seconds
#      SEND/RECV source sites        = 4.0584e-02 seconds
#    Time accumulating tallies       = 2.8365e+00 seconds
#    Time writing statepoints        = 6.8860e-03 seconds
#  Total time for finalization       = 2.7530e-06 seconds
#  Total time elapsed                = 9.9324e+00 seconds
#  Calculation Rate (inactive)       = 701826 particles/second
#  Calculation Rate (active)         = 523385 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 2.26569 +/- 0.00088
#  k-effective (Track-length)  = 2.26575 +/- 0.00097
#  k-effective (Absorption)    = 2.26379 +/- 0.00017
#  Combined k-effective        = 2.26394 +/- 0.00015
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# Load the last statepoint file
sp = openmc.StatePoint(sp_file)

# %%
# Initialize MGXS Library with OpenMC statepoint data
mgxs_lib.load_from_statepoint(sp)

# %%
mgxs_file = mgxs_lib.create_mg_library(xs_type = 'macro')
mgxs_file.export_to_hdf5(filename = 'Oralloy/oralloy.h5')

# %%
sp.close()
